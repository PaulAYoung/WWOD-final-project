# %%
import os
import pandas as pd

# %%
data_path = os.path.join(os.path.pardir, "compileddata")
assert os.path.exists(data_path)

# %%
df = pd.read_csv(os.path.join(data_path, "graduates.csv"))
df.head()
# Out:
#    Unnamed: 0           FILENAME  african_am  am_ind  asian  black  \
# 0           0  data/gradaf12.txt           2       0     13    NaN
# 1           1  data/gradaf12.txt          35       0      2    NaN
# 2           2  data/gradaf12.txt           9       0      1    NaN
# 3           3  data/gradaf12.txt           0       0      0    NaN
# 4           4  data/gradaf12.txt           0       0      0    NaN
#
#         cds_code           county  \
# 0  1100170109835  Alameda
# 1  1100170112607  Alameda
# 2  1100170118489  Alameda
# 3  1100170130401  Alameda
# 4  1100170130419  Alameda
#
#                                             district  filipino  hispanic  \
# 0  Alameda County Office of Education            ...         0         4
# 1  Alameda County Office of Education            ...         0        11
# 2  Alameda County Office of Education            ...         2        22
# 3  Alameda County Office of Education            ...         0         0
# ...

# %%
pivot = df.pivot_table(values="total", rows="county", cols="year", aggfunc=sum).head()

# %%
pivot.ix["Alameda"]
# Out:
# year
# 1       311
# 102     410
# 203     373
# 304     421
# 405     370
# 506     444
# 607     474
# 708     NaN
# 809     NaN
# 910     NaN
# 1011    NaN
# 1112    NaN
# 9495    288
# 9596    223
# 9697    255
# 9798    280
# 9899    289
# 9900    280
# Name: Alameda, dtype: float64
